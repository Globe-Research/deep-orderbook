# %%
# !pip install keras-tcn
# Out:
# Requirement already satisfied: keras-tcn in /opt/conda/lib/python3.7/site-packages (3.1.1)
# Requirement already satisfied: numpy>=1.18.1 in /opt/conda/lib/python3.7/site-packages (from keras-tcn) (1.18.5)
# Requirement already satisfied: keras==2.3.1 in /opt/conda/lib/python3.7/site-packages (from keras-tcn) (2.3.1)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.7/site-packages (from keras==2.3.1->keras-tcn) (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/conda/lib/python3.7/site-packages (from keras==2.3.1->keras-tcn) (1.0.8)
# Requirement already satisfied: scipy>=0.14 in /opt/conda/lib/python3.7/site-packages (from keras==2.3.1->keras-tcn) (1.4.1)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras==2.3.1->keras-tcn) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.7/site-packages (from keras==2.3.1->keras-tcn) (1.1.2)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from keras==2.3.1->keras-tcn) (5.3.1)

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import os
import gc

# %%
paths = './content/coinbase_btc_usd/coinbase/btc_usd/l2_snapshots/100ms/'

# %%
def concat_data(base_path):
    """Concatenate all the files in basepath keeping only the
    columns specified by features.
    """
    l2_snapshot = pd.DataFrame()
    for i, x in enumerate(tqdm(sorted(os.listdir(base_path)))):
        if base_path is None:
            path = x
        else:
            path = base_path + x
        df_hour = pd.read_parquet(path)
        l2_snapshot = pd.concat([l2_snapshot, df_hour.dropna()])
        
    return l2_snapshot

def extend_matrix(A, n):
    """Extend a matrix A by duplicating rows as specified by the list n."""
    n = n[1:]  # Do not duplicate rows for the first day
    A = A[:-1]  # Do not duplicate the last day's row
    A = np.repeat(A, repeats=n, axis=0)
    return A

def normalise_data_per_day(df):
    df_mean = df.resample('D').mean()
    df_var = df.resample('D').var()
    
    timestamps_per_day = np.unique(df.index.date, return_counts=True)[1]
    mean_array = extend_matrix(df_mean.to_numpy(), timestamps_per_day)
    var_array = extend_matrix(df_var.to_numpy(), timestamps_per_day)
    
    # Drop the rows of the first day
    df = df[df.index.date != df.index[0].date()]
    
    df = (df - mean_array) / np.sqrt(var_array)

    return df

def balance_classes(y):
    unique = np.unique(y, return_counts=True)

    # Take smallest number as class size
    class_size = np.min(unique[1])
    class_size_index = np.argmin(unique[1])
    timestamps = np.array([], dtype=int)
    for i, category in enumerate(unique[0]):
        if i == class_size_index:
            continue
        index = np.argwhere(y==category)
        index = index.reshape(len(index))
        random_timestamps = np.random.choice(index, (unique[1][i] - class_size), replace=False)
        timestamps = np.concatenate((timestamps, random_timestamps), axis=None)
        
    return timestamps

def generate_y(df_snapshot, k, T=100, D=40, best_ask='a1', best_bid='b1', alpha=10e-5):
    """Return X, y from the snapshot dataframe and the best ask/bid columns."""
    df = pd.DataFrame()
    df['mid_price'] = (df_snapshot[best_ask].to_numpy()+df_snapshot[best_bid].to_numpy())/2

    # Create columns delayed by -k to k-1
    for i in range(-k, k):
        df[i] = df['mid_price'].shift(periods=i)

    # Drop first k-1 rows and last k rows
    df.drop(range(0,k), axis=0, inplace=True)
    df.drop(range(len(df_snapshot)-k,len(df_snapshot)), axis=0, inplace=True)
    
    # Compute mean of previous k and next k
    df['m_b'] = df[range(0,k)].mean(axis=1)
    df['m_a'] = df[range(-k,0)].mean(axis=1)
    
    # Compute label of increasing or decreasing
    y_increase = np.where(df['m_b'] > df['m_a'] * (1+alpha), 1, 0)
    y_decrease = np.where(df['m_b'] < df['m_a'] * (1-alpha), -1, 0)
    y = y_increase + y_decrease

    # 100 most recent limit orders used so ignore first 100 timesteps
    y = y[T:]
    y += 1

    return y

def generate_preX(df_snapshot, k):
    preX = df_snapshot.to_numpy()[k:-k]

    return preX

def generate_X(preX, T=100, D=40):
    # For each timestep create matrix of 100 most recent limit orders
    X = np.array([preX[t:t+T] for t in range(len(preX)-T)], dtype='float32')
        
    return X

# %%
# l2_snap = pd.read_csv('total.csv', index_col=0, infer_datetime_format=True)
l2_snap = concat_data(paths)
# Out:
# 100%|██████████| 216/216 [08:02<00:00,  2.23s/it]

# %%
l2_snap.head()
# Out:
#                               b1       b2       b3       b4      b5       b6  \
# timestamp
# 2019-11-12 00:00:00.000  8721.53  8720.59  8719.55  8719.50  8719.0  8718.02
# 2019-11-12 00:00:00.100  8721.53  8720.59  8719.56  8719.55  8719.0  8718.02
# 2019-11-12 00:00:00.200  8721.53  8720.59  8719.61  8719.56  8719.0  8718.02
# 2019-11-12 00:00:00.300  8721.53  8720.59  8719.61  8719.56  8719.0  8718.02
# 2019-11-12 00:00:00.400  8721.53  8720.59  8719.61  8719.56  8719.0  8718.99
#
#                               b7       b8       b9      b10  ...      aq41  \
# timestamp                                                    ...
# 2019-11-12 00:00:00.000  8717.87  8717.85  8717.56  8716.06  ...  8.200000
# 2019-11-12 00:00:00.100  8717.87  8717.85  8717.56  8716.06  ...  8.200000
# 2019-11-12 00:00:00.200  8717.87  8717.85  8716.06  8716.00  ...  0.009135
# 2019-11-12 00:00:00.300  8718.00  8717.87  8717.85  8716.60  ...  0.009135
# 2019-11-12 00:00:00.400  8718.02  8718.00  8717.87  8717.85  ...  0.009135
#
#                           aq42   aq43   aq44   aq45      aq46      aq47  \
# timestamp
# 2019-11-12 00:00:00.000  2.203  2.600  0.005  2.500  0.896321  0.766000
# 2019-11-12 00:00:00.100  2.203  2.600  0.005  2.500  0.896321  0.766000
# 2019-11-12 00:00:00.200  8.200  2.203  2.600  0.005  2.500000  0.896321
# 2019-11-12 00:00:00.300  8.200  2.203  2.600  0.005  2.500000  0.896321
# 2019-11-12 00:00:00.400  8.200  2.203  2.600  0.005  2.500000  0.896321
#
#                              aq48      aq49      aq50
# timestamp
# 2019-11-12 00:00:00.000  0.001737  1.820000  0.933419
# 2019-11-12 00:00:00.100  0.001737  1.820000  0.933419
# 2019-11-12 00:00:00.200  0.766000  0.001737  1.820000
# 2019-11-12 00:00:00.300  0.766000  0.001737  1.820000
# 2019-11-12 00:00:00.400  0.766000  0.001737  1.820000
#
# [5 rows x 200 columns]

# %%
l2_snap.tail()
# Out:
#                               b1       b2       b3       b4       b5       b6  \
# timestamp
# 2019-11-20 23:59:57.900  8082.96  8082.23  8081.65  8080.17  8079.74  8079.69
# 2019-11-20 23:59:58.400  8082.96  8082.23  8081.65  8080.17  8079.74  8079.69
# 2019-11-20 23:59:58.500  8082.96  8082.23  8081.65  8080.17  8079.74  8079.69
# 2019-11-20 23:59:58.800  8082.96  8082.23  8081.65  8080.17  8079.74  8079.69
# 2019-11-20 23:59:59.600  8082.96  8082.23  8081.65  8080.17  8079.74  8079.69
#
#                               b7       b8      b9      b10  ...   aq41  \
# timestamp                                                   ...
# 2019-11-20 23:59:57.900  8079.19  8077.75  8077.6  8076.88  ...  0.005
# 2019-11-20 23:59:58.400  8079.19  8077.75  8077.6  8076.88  ...  0.005
# 2019-11-20 23:59:58.500  8079.19  8077.75  8077.6  8076.88  ...  0.005
# 2019-11-20 23:59:58.800  8079.19  8077.75  8077.6  8076.88  ...  0.005
# 2019-11-20 23:59:59.600  8079.19  8077.75  8077.6  8076.88  ...  0.005
#
#                              aq42    aq43   aq44  aq45      aq46   aq47  \
# timestamp
# 2019-11-20 23:59:57.900  0.151276  0.0058  1.137   0.6  0.907671  0.001
# 2019-11-20 23:59:58.400  0.151276  0.0058  1.137   0.6  0.907671  0.001
# 2019-11-20 23:59:58.500  0.151276  0.0058  1.137   0.6  0.907671  0.001
# 2019-11-20 23:59:58.800  0.151276  0.0058  1.137   0.6  0.907671  0.001
# 2019-11-20 23:59:59.600  0.151276  0.0058  1.137   0.6  0.907671  0.001
#
#                           aq48  aq49     aq50
# timestamp
# 2019-11-20 23:59:57.900  0.001   2.4  0.74149
# 2019-11-20 23:59:58.400  0.001   2.4  0.74149
# 2019-11-20 23:59:58.500  0.001   2.4  0.74149
# 2019-11-20 23:59:58.800  0.001   2.4  0.74149
# 2019-11-20 23:59:59.600  0.001   2.4  0.74149
#
# [5 rows x 200 columns]

# %% [markdown]
# ## Generic Model and Depth Data Generation

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras import Input, Model
from tcn import TCN, tcn_full_summary
from tensorflow import keras

# %%
def generate_model(depth):
    strategy = tf.distribute.MirroredStrategy()
    with strategy.scope():

        i = Input(batch_shape=(None, 100, depth))
        o = TCN(return_sequences=False, use_skip_connections=True, dropout_rate=0.4, dilations=[1, 2, 4, 8, 16, 32, 64], use_batch_norm=True)(i)
        o = Dense(3, activation='softmax')(o)
        m = Model(inputs=[i], outputs=[o])
        opt = keras.optimizers.Adam(learning_rate=0.01)
        m.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
        
        return m

# %%
def generate_data(l2_snap, depth, columns, days_training, k=20):
    l2_snap.index = pd.to_datetime(l2_snap.index)
    l2_snap_dep2 = l2_snap.loc[:,columns]
    l2_norm = normalise_data_per_day(l2_snap_dep2)
    T = 100
    D = depth
    y = generate_y(l2_norm, T=T, D=D, best_ask='a1', best_bid = 'b1', alpha=0.002, k=k)
    preX = generate_preX(l2_norm, k=k)
    print("preX Shape: ", preX.shape)
    X = generate_X(preX)
    print("X shape, y shape: ", X.shape, y.shape)
    print("Unique y's: ", np.unique(y))

    del preX
    gc.collect()

    # First and last 20 are removed to create labels and then last 100 as previous 100 is required for input matrix
    X_index = l2_norm[20:-120].index

    # Number of data points for the last day
    num_test = np.unique(X_index.day, return_counts=True)[1][-1]

    # Days back to
    num_start = np.unique(X_index.day, return_counts=True)[1][-1 - days_training:].sum()

    # Split the data into the first days and the last day
    X_train_val = X[-num_start:-num_test]
    y_train_val = y[-num_start:-num_test]
    X_test = X[-num_test:]
    y_test = y[-num_test:]
    return X_train_val, y_train_val, X_test, y_test

# %% [markdown]
# ## Depth:10
#
#
# #### Days 1, 2, 4, 7

# %%
days_training = 1
for k in [20, 2, 5, 20, 200, 600, 1]:
    print('Days Training now ', days_training)
    print('K :', k)
    X_train_val, y_train_val, X_test, y_test = generate_data(l2_snap, 40, columns = ['b1','b2','b3','b4','b5','b6','b7','b8', 'b9', 'b10', 'a1','a2','a3','a4','a5','a6','a7','a8', 'a9', 'a10', 'bq1','bq2','bq3','bq4','bq5','bq6','bq7','bq8', 'bq9', 'bq10', 'aq1','aq2','aq3','aq4','aq5','aq6','aq7','aq8', 'aq9', 'aq10'], days_training=days_training, k=k)
    m = generate_model(40)
    from sklearn.utils.class_weight import compute_class_weight
    class_weights = compute_class_weight('balanced', np.unique(y_train_val), y_train_val)
    d_class_weights = dict(enumerate(class_weights))

    EPOCHS = 20
    model_filename = "model_resnet_walkforward_tcn_depth10.h5"
    hist_filename = "hist_model_walkforward_tcn_depth10.csv"
    early_stop = keras.callbacks.EarlyStopping(
                    monitor='val_loss',
                    patience=4)
    model_save_checkpoint = keras.callbacks.ModelCheckpoint(
                                filepath= model_filename,
                                save_best_only=True,
                                monitor='val_loss',
                                verbose=1)
    reduce_lr = keras.callbacks.ReduceLROnPlateau(
                    monitor='val_loss',
                    factor=0.5,
                    patience=2,
                    verbose=1,
                    min_lr=0.0001)
    callbacks = [reduce_lr, model_save_checkpoint, early_stop]
    history = m.fit(
                X_train_val, y_train_val,
                epochs=EPOCHS,
                batch_size=128,
                callbacks=callbacks,
                class_weight = d_class_weights,
                validation_data = (X_test, y_test),
    )

    y_pred = m.predict(X_test).argmax(axis=1)

    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import seaborn as sns
    sns.set()
    cm = confusion_matrix(y_pred=y_pred, y_true=y_test)

    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    ax=sns.heatmap(cm, annot=True, xticklabels=['Down','Stable','Up'], yticklabels=['Down','Stable','Up'], cmap='Blues')
    ax.set_ylim(3.0, 0)
    plt.savefig('image_depth_10_{}_days_training'.format(days_training))

    from sklearn.metrics import classification_report
    print(classification_report(y_true = y_test,y_pred = y_pred,  target_names=['Down', 'Stable', 'Up']))
# Out:
# Days Training now  1
# K : 20
# preX Shape:  (4220032, 40)
# X shape, y shape:  (4219932, 100, 40) (4219932,)
# Unique y's:  [0 1 2]
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py:71: FutureWarning: Pass classes=[0 1 2], y=[1 1 1 ... 1 1 1] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# Epoch 1/20
# INFO:tensorflow:batch_all_reduce: 60 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 60 all-reduces with algorithm = nccl, num_packs = 1
# 4128/4128 [==============================] - ETA: 0s - accuracy: 0.4850 - loss: 0.7585
# Epoch 00001: val_loss improved from inf to 1.22871, saving model to model_resnet_walkforward_tcn_depth10.h5
# 4128/4128 [==============================] - 143s 35ms/step - accuracy: 0.4850 - loss: 0.7585 - val_accuracy: 0.3696 - val_loss: 1.2287 - lr: 0.0100
# Epoch 2/20
# 4128/4128 [==============================] - ETA: 0s - accuracy: 0.5560 - loss: 0.6818
# Epoch 00002: val_loss did not improve from 1.22871
# 4128/4128 [==============================] - 137s 33ms/step - accuracy: 0.5560 - loss: 0.6818 - val_accuracy: 0.5163 - val_loss: 1.3718 - lr: 0.0100
# Epoch 3/20
# 4127/4128 [============================>.] - ETA: 0s - accuracy: 0.5703 - loss: 0.6659
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00003: val_loss did not improve from 1.22871
# 4128/4128 [==============================] - 133s 32ms/step - accuracy: 0.5703 - loss: 0.6659 - val_accuracy: 0.4267 - val_loss: 2.6289 - lr: 0.0100
# Epoch 4/20
# 4126/4128 [============================>.] - ETA: 0s - accuracy: 0.5901 - loss: 0.6348
# Epoch 00004: val_loss did not improve from 1.22871
# 4128/4128 [==============================] - 131s 32ms/step - accuracy: 0.5901 - loss: 0.6349 - val_accuracy: 0.5622 - val_loss: 2.7027 - lr: 0.0050
# Epoch 5/20
# 4127/4128 [============================>.] - ETA: 0s - accuracy: 0.5990 - loss: 0.6229
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 00005: val_loss did not improve from 1.22871
# 4128/4128 [==============================] - 133s 32ms/step - accuracy: 0.5990 - loss: 0.6229 - val_accuracy: 0.5309 - val_loss: 2.7238 - lr: 0.0050
#               precision    recall  f1-score   support
#
#         Down       0.28      0.48      0.35     61142
#       Stable       0.80      0.54      0.64    350499
#           Up       0.24      0.56      0.34     53759
#
#     accuracy                           0.53    465400
#    macro avg       0.44      0.52      0.44    465400
# weighted avg       0.67      0.53      0.57    465400
#
# Days Training now  1
# K : 2
# preX Shape:  (4220068, 40)
# X shape, y shape:  (4219968, 100, 40) (4219968,)
# Unique y's:  [0 1 2]
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py:71: FutureWarning: Pass classes=[0 1 2], y=[1 1 1 ... 1 1 1] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# Epoch 1/20
# INFO:tensorflow:batch_all_reduce: 60 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 60 all-reduces with algorithm = nccl, num_packs = 1
# 4128/4128 [==============================] - ETA: 0s - accuracy: 0.3068 - loss: 0.8918
# Epoch 00001: val_loss improved from inf to 1.27905, saving model to model_resnet_walkforward_tcn_depth10.h5
# 4128/4128 [==============================] - 140s 34ms/step - accuracy: 0.3068 - loss: 0.8918 - val_accuracy: 0.1254 - val_loss: 1.2791 - lr: 0.0100
# Epoch 2/20
# 4127/4128 [============================>.] - ETA: 0s - accuracy: 0.2833 - loss: 0.8140
# Epoch 00002: val_loss improved from 1.27905 to 1.09641, saving model to model_resnet_walkforward_tcn_depth10.h5
# 4128/4128 [==============================] - 133s 32ms/step - accuracy: 0.2833 - loss: 0.8140 - val_accuracy: 0.2902 - val_loss: 1.0964 - lr: 0.0100
# Epoch 3/20
# 4128/4128 [==============================] - ETA: 0s - accuracy: 0.3034 - loss: 0.7917
# Epoch 00003: val_loss improved from 1.09641 to 0.98472, saving model to model_resnet_walkforward_tcn_depth10.h5
# 4128/4128 [==============================] - 136s 33ms/step - accuracy: 0.3034 - loss: 0.7917 - val_accuracy: 0.3885 - val_loss: 0.9847 - lr: 0.0100
# Epoch 4/20
# 4127/4128 [============================>.] - ETA: 0s - accuracy: 0.2963 - loss: 0.7815
# Epoch 00004: val_loss did not improve from 0.98472
# 4128/4128 [==============================] - 138s 33ms/step - accuracy: 0.2963 - loss: 0.7814 - val_accuracy: 0.2056 - val_loss: 9.9222 - lr: 0.0100
# Epoch 5/20
# 4127/4128 [============================>.] - ETA: 0s - accuracy: 0.3143 - loss: 0.7703
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00005: val_loss did not improve from 0.98472
# 4128/4128 [==============================] - 138s 33ms/step - accuracy: 0.3143 - loss: 0.7703 - val_accuracy: 0.3628 - val_loss: 7.3314 - lr: 0.0100
# Epoch 6/20
# 4128/4128 [==============================] - ETA: 0s - accuracy: 0.3326 - loss: 0.7454
# Epoch 00006: val_loss did not improve from 0.98472
# 4128/4128 [==============================] - 132s 32ms/step - accuracy: 0.3326 - loss: 0.7454 - val_accuracy: 0.3351 - val_loss: 10.4607 - lr: 0.0050
# Epoch 7/20
# 4127/4128 [============================>.] - ETA: 0s - accuracy: 0.3427 - loss: 0.7349
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 00007: val_loss did not improve from 0.98472
# 4128/4128 [==============================] - 134s 32ms/step - accuracy: 0.3427 - loss: 0.7349 - val_accuracy: 0.4066 - val_loss: 3.9425 - lr: 0.0050
#               precision    recall  f1-score   support
#
#         Down       0.04      0.41      0.07     11871
#       Stable       0.95      0.40      0.57    441809
#           Up       0.04      0.54      0.08     11720
#
#     accuracy                           0.41    465400
#    macro avg       0.34      0.45      0.24    465400
# weighted avg       0.90      0.41      0.54    465400
#
# Days Training now  1
# K : 5
# preX Shape:  (4220062, 40)
# X shape, y shape:  (4219962, 100, 40) (4219962,)
# Unique y's:  [0 1 2]
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# Epoch 1/20
# INFO:tensorflow:batch_all_reduce: 60 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 60 all-reduces with algorithm = nccl, num_packs = 1
# 4128/4128 [==============================] - ETA: 0s - accuracy: 0.3608 - loss: 0.8135
# Epoch 00001: val_loss improved from inf to 1.39960, saving model to model_resnet_walkforward_tcn_depth10.h5
# 4128/4128 [==============================] - 135s 33ms/step - accuracy: 0.3608 - loss: 0.8135 - val_accuracy: 0.2393 - val_loss: 1.3996 - lr: 0.0100
# Epoch 2/20
# 4127/4128 [============================>.] - ETA: 0s - accuracy: 0.4031 - loss: 0.7257
# Epoch 00002: val_loss did not improve from 1.39960
# 4128/4128 [==============================] - 138s 34ms/step - accuracy: 0.4031 - loss: 0.7257 - val_accuracy: 0.2403 - val_loss: 2.6251 - lr: 0.0100
# Epoch 3/20
# 4128/4128 [==============================] - ETA: 0s - accuracy: 0.4354 - loss: 0.7074
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00003: val_loss did not improve from 1.39960
# 4128/4128 [==============================] - 133s 32ms/step - accuracy: 0.4354 - loss: 0.7074 - val_accuracy: 0.2814 - val_loss: 4.5630 - lr: 0.0100
# Epoch 4/20
# 4127/4128 [============================>.] - ETA: 0s - accuracy: 0.4645 - loss: 0.6756
# Epoch 00004: val_loss did not improve from 1.39960
# 4128/4128 [==============================] - 138s 33ms/step - accuracy: 0.4645 - loss: 0.6756 - val_accuracy: 0.4110 - val_loss: 2.4739 - lr: 0.0050
# Epoch 5/20
# 4127/4128 [============================>.] - ETA: 0s - accuracy: 0.4815 - loss: 0.6647
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 00005: val_loss did not improve from 1.39960
# 4128/4128 [==============================] - 134s 33ms/step - accuracy: 0.4815 - loss: 0.6646 - val_accuracy: 0.4187 - val_loss: 2.1519 - lr: 0.0050
#               precision    recall  f1-score   support
#
#         Down       0.09      0.43      0.14     23521
#       Stable       0.91      0.41      0.56    419873
#           Up       0.08      0.62      0.15     22006
#
#     accuracy                           0.42    465400
#    macro avg       0.36      0.48      0.29    465400
# weighted avg       0.83      0.42      0.52    465400
#
# Days Training now  1
# K : 20
# preX Shape:  (4220032, 40)
# X shape, y shape:  (4219932, 100, 40) (4219932,)
# Unique y's:  [0 1 2]
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# Epoch 1/20
# INFO:tensorflow:batch_all_reduce: 60 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 60 all-reduces with algorithm = nccl, num_packs = 1
# 4126/4128 [============================>.] - ETA: 0s - accuracy: 0.4869 - loss: 0.7522
# Epoch 00001: val_loss improved from inf to 1.34466, saving model to model_resnet_walkforward_tcn_depth10.h5
# 4128/4128 [==============================] - 138s 33ms/step - accuracy: 0.4870 - loss: 0.7522 - val_accuracy: 0.3951 - val_loss: 1.3447 - lr: 0.0100
# Epoch 2/20
# 4127/4128 [============================>.] - ETA: 0s - accuracy: 0.5613 - loss: 0.6798
# Epoch 00002: val_loss did not improve from 1.34466
# 4128/4128 [==============================] - 132s 32ms/step - accuracy: 0.5613 - loss: 0.6798 - val_accuracy: 0.3981 - val_loss: 1.6666 - lr: 0.0100
# Epoch 3/20
# 4126/4128 [============================>.] - ETA: 0s - accuracy: 0.5763 - loss: 0.6640
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00003: val_loss did not improve from 1.34466
# 4128/4128 [==============================] - 130s 32ms/step - accuracy: 0.5763 - loss: 0.6640 - val_accuracy: 0.4050 - val_loss: 1.5858 - lr: 0.0100
# Epoch 4/20
# 4126/4128 [============================>.] - ETA: 0s - accuracy: 0.5972 - loss: 0.6323
# Epoch 00004: val_loss did not improve from 1.34466
# 4128/4128 [==============================] - 143s 35ms/step - accuracy: 0.5973 - loss: 0.6323 - val_accuracy: 0.4652 - val_loss: 1.7830 - lr: 0.0050
# Epoch 5/20
# 4126/4128 [============================>.] - ETA: 0s - accuracy: 0.6041 - loss: 0.6191
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 00005: val_loss did not improve from 1.34466
# 4128/4128 [==============================] - 133s 32ms/step - accuracy: 0.6042 - loss: 0.6191 - val_accuracy: 0.4818 - val_loss: 2.6278 - lr: 0.0050
#               precision    recall  f1-score   support
#
#         Down       0.26      0.45      0.33     61142
#       Stable       0.80      0.47      0.59    350499
#           Up       0.21      0.61      0.31     53759
#
#     accuracy                           0.48    465400
#    macro avg       0.42      0.51      0.41    465400
# weighted avg       0.66      0.48      0.52    465400
#
# Days Training now  1
# K : 200
# preX Shape:  (4219672, 40)
# X shape, y shape:  (4219572, 100, 40) (4219572,)
# Unique y's:  [0 1 2]
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py:71: FutureWarning: Pass classes=[0 1 2], y=[0 0 0 ... 0 0 0] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# Epoch 1/20
# INFO:tensorflow:batch_all_reduce: 60 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 60 all-reduces with algorithm = nccl, num_packs = 1
# 4127/4128 [============================>.] - ETA: 0s - accuracy: 0.5943 - loss: 0.8701
# Epoch 00001: val_loss improved from inf to 1.61902, saving model to model_resnet_walkforward_tcn_depth10.h5
# 4128/4128 [==============================] - 134s 32ms/step - accuracy: 0.5943 - loss: 0.8701 - val_accuracy: 0.6316 - val_loss: 1.6190 - lr: 0.0100
# Epoch 2/20
# 4127/4128 [============================>.] - ETA: 0s - accuracy: 0.6426 - loss: 0.7891
# Epoch 00002: val_loss did not improve from 1.61902
# 4128/4128 [==============================] - 131s 32ms/step - accuracy: 0.6426 - loss: 0.7891 - val_accuracy: 0.6093 - val_loss: 2.3873 - lr: 0.0100
# Epoch 3/20
# 4127/4128 [============================>.] - ETA: 0s - accuracy: 0.6668 - loss: 0.7462
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00003: val_loss did not improve from 1.61902
# 4128/4128 [==============================] - 133s 32ms/step - accuracy: 0.6668 - loss: 0.7462 - val_accuracy: 0.6201 - val_loss: 3.0992 - lr: 0.0100
# Epoch 4/20
# 4127/4128 [============================>.] - ETA: 0s - accuracy: 0.6963 - loss: 0.6917
# Epoch 00004: val_loss did not improve from 1.61902
# 4128/4128 [==============================] - 132s 32ms/step - accuracy: 0.6963 - loss: 0.6917 - val_accuracy: 0.6124 - val_loss: 3.2641 - lr: 0.0050
# Epoch 5/20
# 4128/4128 [==============================] - ETA: 0s - accuracy: 0.7073 - loss: 0.6695
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 00005: val_loss did not improve from 1.61902
# 4128/4128 [==============================] - 132s 32ms/step - accuracy: 0.7073 - loss: 0.6695 - val_accuracy: 0.6137 - val_loss: 3.4811 - lr: 0.0050
#               precision    recall  f1-score   support
#
#         Down       0.67      0.69      0.68    193800
#       Stable       0.43      0.12      0.18     90310
#           Up       0.59      0.78      0.67    181290
#
#     accuracy                           0.61    465400
#    macro avg       0.56      0.53      0.51    465400
# weighted avg       0.59      0.61      0.58    465400
#
# Days Training now  1
# K : 600
# preX Shape:  (4218872, 40)
# X shape, y shape:  (4218772, 100, 40) (4218772,)
# Unique y's:  [0 1 2]
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# Epoch 1/20
# 4127/4128 [============================>.] - ETA: 0s - accuracy: 0.5693 - loss: 0.9746
# Epoch 00001: val_loss improved from inf to 1.37162, saving model to model_resnet_walkforward_tcn_depth10.h5
# 4128/4128 [==============================] - 136s 33ms/step - accuracy: 0.5693 - loss: 0.9746 - val_accuracy: 0.6409 - val_loss: 1.3716 - lr: 0.0100
# Epoch 2/20
# 4128/4128 [==============================] - ETA: 0s - accuracy: 0.6107 - loss: 0.9038
# Epoch 00002: val_loss did not improve from 1.37162
# 4128/4128 [==============================] - 130s 32ms/step - accuracy: 0.6107 - loss: 0.9038 - val_accuracy: 0.5888 - val_loss: 6.6320 - lr: 0.0100
# Epoch 3/20
# 4127/4128 [============================>.] - ETA: 0s - accuracy: 0.6422 - loss: 0.8489
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00003: val_loss did not improve from 1.37162
# 4128/4128 [==============================] - 136s 33ms/step - accuracy: 0.6422 - loss: 0.8489 - val_accuracy: 0.6134 - val_loss: 6.3509 - lr: 0.0100
# Epoch 4/20
# 4127/4128 [============================>.] - ETA: 0s - accuracy: 0.6716 - loss: 0.7863
# Epoch 00004: val_loss did not improve from 1.37162
# 4128/4128 [==============================] - 131s 32ms/step - accuracy: 0.6716 - loss: 0.7863 - val_accuracy: 0.6259 - val_loss: 6.8376 - lr: 0.0050
# Epoch 5/20
# 4126/4128 [============================>.] - ETA: 0s - accuracy: 0.6836 - loss: 0.7567
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 00005: val_loss did not improve from 1.37162
# 4128/4128 [==============================] - 133s 32ms/step - accuracy: 0.6836 - loss: 0.7567 - val_accuracy: 0.6179 - val_loss: 9.3901 - lr: 0.0050
#               precision    recall  f1-score   support
#
#         Down       0.61      0.74      0.66    226087
#       Stable       0.16      0.05      0.08     17880
#           Up       0.65      0.54      0.59    221433
#
#     accuracy                           0.62    465400
#    macro avg       0.47      0.44      0.44    465400
# weighted avg       0.61      0.62      0.61    465400
#
# Days Training now  1
# K : 1
# preX Shape:  (4220070, 40)
# X shape, y shape:  (4219970, 100, 40) (4219970,)
# Unique y's:  [0 1 2]
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# Epoch 1/20
# 4128/4128 [==============================] - ETA: 0s - accuracy: 0.3118 - loss: 1.0330
# Epoch 00001: val_loss improved from inf to 0.93459, saving model to model_resnet_walkforward_tcn_depth10.h5
# 4128/4128 [==============================] - 136s 33ms/step - accuracy: 0.3118 - loss: 1.0330 - val_accuracy: 0.4708 - val_loss: 0.9346 - lr: 0.0100
# Epoch 2/20
# 4127/4128 [============================>.] - ETA: 0s - accuracy: 0.2521 - loss: 0.9093
# Epoch 00002: val_loss did not improve from 0.93459
# 4128/4128 [==============================] - 132s 32ms/step - accuracy: 0.2521 - loss: 0.9093 - val_accuracy: 0.0625 - val_loss: 1.5694 - lr: 0.0100
# Epoch 3/20
# 4126/4128 [============================>.] - ETA: 0s - accuracy: 0.2832 - loss: 0.8874
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00003: val_loss did not improve from 0.93459
# 4128/4128 [==============================] - 129s 31ms/step - accuracy: 0.2832 - loss: 0.8874 - val_accuracy: 0.0949 - val_loss: 3.3924 - lr: 0.0100
# Epoch 4/20
# 4127/4128 [============================>.] - ETA: 0s - accuracy: 0.2765 - loss: 0.8473
# Epoch 00004: val_loss did not improve from 0.93459
# 4128/4128 [==============================] - 139s 34ms/step - accuracy: 0.2765 - loss: 0.8472 - val_accuracy: 0.1446 - val_loss: 3.4007 - lr: 0.0050
# Epoch 5/20
# 4128/4128 [==============================] - ETA: 0s - accuracy: 0.2882 - loss: 0.8395
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 00005: val_loss did not improve from 0.93459
# 4128/4128 [==============================] - 134s 33ms/step - accuracy: 0.2882 - loss: 0.8395 - val_accuracy: 0.2904 - val_loss: 2.5675 - lr: 0.0050
#               precision    recall  f1-score   support
#
#         Down       0.02      0.55      0.03      6011
#       Stable       0.98      0.28      0.44    453272
#           Up       0.02      0.51      0.04      6117
#
#     accuracy                           0.29    465400
#    macro avg       0.34      0.45      0.17    465400
# weighted avg       0.95      0.29      0.43    465400

# %%
plt.plot([1,2,5,20,200,600], [0.29, 0.41, 0.42, 0.53, 0.61, 0.62])
plt.ylabel('Walk-forward accuracy')
plt.xlabel('Time Horizon k')
plt.ylim([0, 0.7])
plt.savefig('walkforward_days_training')

# %%
plt.plot([0.1,0.2,0.5,2,20,60], [0.29, 0.41, 0.42, 0.53, 0.61, 0.62])
plt.ylabel('Walk-forward accuracy')
plt.xlabel('Time Horizon s')
plt.ylim([0, 0.7])
plt.savefig('walkforward_days_training')

# %%
plt.plot([0.1,0.2,0.5,2,20,60], [0.29, 0.41, 0.42, 0.53, 0.61, 0.62])
plt.ylabel('Walk-forward accuracy')
plt.xlabel('Time Horizon s')
plt.ylim([0, 0.7])
# plt.savefig('walkforward_days_training')
# Out:
# (0.0, 0.7)

# %%
plt.bar([10,2,4,7], [0.57, 0.43, 0.57, 0.67])
plt.ylabel('Walk-forward accuracy')
plt.xlabel('Days used for training')
# Out:
# Text(0.5, 0, 'Days used for training')

# %% [markdown]
# ## Depth 5

# %%
# X_train_val, y_train_val, X_test, y_test = generate_data(l2_snap, 20, columns = ['b1','b2','b3','b4','b5', 'a1','a2','a3','a4','a5', 'bq1','bq2','bq3','bq4','bq5', 'aq1','aq2','aq3','aq4','aq5'] )

# %%
# m = generate_model(20)
# from sklearn.utils.class_weight import compute_class_weight
# class_weights = compute_class_weight('balanced', np.unique(y_train_val), y_train_val)
# d_class_weights = dict(enumerate(class_weights))

# %%
# EPOCHS = 20
# model_filename = "model_resnet_walkforward_tcn_depth5.h5"
# hist_filename = "hist_model_walkforward_tcn_depth5.csv"
# early_stop = keras.callbacks.EarlyStopping(
#                 monitor='val_loss',
#                 patience=4)
# model_save_checkpoint = keras.callbacks.ModelCheckpoint(
#                             filepath= model_filename,
#                             save_best_only=True,
#                             monitor='val_loss',
#                             verbose=1)
# reduce_lr = keras.callbacks.ReduceLROnPlateau(
#                 monitor='val_loss',
#                 factor=0.5,
#                 patience=2,
#                 verbose=1,
#                 min_lr=0.0001)
# callbacks = [reduce_lr, model_save_checkpoint, early_stop]
# history = m.fit(
#             X_train_val, y_train_val,
#             epochs=EPOCHS,
#             batch_size=128,
#             callbacks=callbacks,
#             class_weight = d_class_weights,
#             validation_data = (X_test, y_test),
# )

# %%
# y_pred = m.predict(X_test).argmax(axis=1)

# %%
# from sklearn.metrics import confusion_matrix
# import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set()
# cm = confusion_matrix(y_pred=y_pred, y_true=y_test)
    
# cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# ax=sns.heatmap(cm, annot=True, xticklabels=['Down','Stable','Up'], yticklabels=['Down','Stable','Up'], cmap='Blues')
# ax.set_ylim(3.0, 0)
# plt.savefig('image_depth_5')

# %%
# from sklearn.metrics import classification_report
# print(classification_report(y_true = y_test,y_pred = y_pred,  target_names=['Down', 'Stable', 'Up']))

# %% [markdown]
# ## DEPTH 1

# %%
# X_train_val, y_train_val, X_test, y_test = generate_data(l2_snap, 4, columns=['b1','a1','bq1','aq1'])

# %%
# m = generate_model(4)

# %%
# from sklearn.utils.class_weight import compute_class_weight
# class_weights = compute_class_weight('balanced', np.unique(y_train_val), y_train_val)
# d_class_weights = dict(enumerate(class_weights))

# %%
# EPOCHS = 20
# model_filename = "model_resnet_walkforward_tcn.h5"
# hist_filename = "hist_model_walkforward_tcn.csv"
# early_stop = keras.callbacks.EarlyStopping(
#                 monitor='val_loss',
#                 patience=4)
# model_save_checkpoint = keras.callbacks.ModelCheckpoint(
#                             filepath= model_filename,
#                             save_best_only=True,
#                             monitor='val_loss',
#                             verbose=1)
# reduce_lr = keras.callbacks.ReduceLROnPlateau(
#                 monitor='val_loss',
#                 factor=0.5,
#                 patience=2,
#                 verbose=1,
#                 min_lr=0.0001)
# callbacks = [reduce_lr, model_save_checkpoint, early_stop]
# history = m.fit(
#             X_train_val, y_train_val,
#             epochs=EPOCHS,
#             batch_size=128,
#             callbacks=callbacks,
#             class_weight = d_class_weights,
#             validation_data = (X_test, y_test),
# )

# %%
# y_pred = m.predict(X_test).argmax(axis=1)

# %%
# from sklearn.metrics import confusion_matrix
# import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set()
# cm = confusion_matrix(y_pred=y_pred, y_true=y_test)
    
# cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# ax=sns.heatmap(cm, annot=True, xticklabels=['Down','Stable','Up'], yticklabels=['Down','Stable','Up'], cmap='Blues')
# ax.set_ylim(3.0, 0)
# plt.savefig('image_depth_2')

# %%
# from sklearn.metrics import classification_report
# print(classification_report(y_true = y_test,y_pred = y_pred,  target_names=['Down', 'Stable', 'Up']))
